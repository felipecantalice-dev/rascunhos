# %% [markdown]
# # Find a peak element

# %%
a = [1,2,3,1]

# Peccorrer todo o vetor iniciando em 1 ate n - 1
def find(vec):
  for i in range(1, len(a) - 1):
    if vec[i] > vec[i-1] and vec[i] > vec[i+1]:
      return vec[i]

find(a)
# Out:
# 3
