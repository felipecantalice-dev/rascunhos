# %%
import pandas as pd

url = "https://github.com/Bowserinator/Periodic-Table-JSON/blob/ea41119626581350fdcdd9c873de233645a43023/PeriodicTableCSV.csv?raw=true"
try:
    import io
    df = pd.read_csv(url)
except Exception as e:
    print("Error loading CSV data:", e)
    # Handle the error appropriately

# %%
df
# Out:
#             name                                         appearance  \
# 0       Hydrogen                                      colorless gas
# 1         Helium  colorless gas, exhibiting a red-orange glow wh...
# 2        Lithium                                      silvery-white
# 3      Beryllium                                white-gray metallic
# 4          Boron                                        black-brown
# ..           ...                                                ...
# 114    Moscovium                                                NaN
# 115  Livermorium                                                NaN
# 116   Tennessine                                                NaN
# 117    Oganesson                                                NaN
# 118   Ununennium                                                NaN
#
#      atomic_mass      boil                                      category  \
# 0       1.008000    20.271                             diatomic nonmetal
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('block').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
